# %% [markdown]
# # training histories

# %%
import os

import searchnets.plot

# %% [markdown]
# ### feature search *and* spatial configuration search (digital 2 v. 5)

# %%
acc_dir = '/home/bart/Documents/repos/L2M/visual-search-nets/data/experiment_9_high_LR_alexnet_ftr_and_sptl/checkpoints/feature_spatial_alexnet_models/acc_by_epoch_by_set_size'
searchnets.plots.train_history(acc_dir, save_as='train-history-alexnet-feature-spatial-lr0.001.png')

# %%
TEST_RESULTS_DIR = '/home/bart/Documents/repos/L2M/visual-search-nets/data/experiment_9_high_LR_alexnet_ftr_and_sptl/results/feature_spatial_alexnet_models'
sptl_conf_results = os.path.join(TEST_RESULTS_DIR, f'test_alexnet_trained_50_epochs.gz')
title = 'Alexnet trained 50 epochs\non feature and spatial conj. search stimuli\nlearning rate=0.001'
searchnets.plots.acc_v_set_size(results=sptl_conf_results, title=title, save_as='acc-v-set-size-alexnet-feature-spatial-50epochs-lr0.001.png')
