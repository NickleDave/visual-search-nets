# %% [markdown]
# # Visual Search Difficulty dataset results

# %%
# %matplotlib inline
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import searchnets

# %%
FIGDIR = Path(
    '../../paper/fig4'
)

# %% [markdown]
# ### data / results paths

# %%
DATA_ROOT = Path('../../../data')
vsd_results_dir = DATA_ROOT.joinpath('results')
vsd_alexnet_transfer_results_gz = vsd_results_dir.joinpath(
    'VSD_alexnet_transfer_lr_1e-03_no_finetune/'
    'VSD_alexnet_transfer_lr_1e-03_no_finetune_trained_200_epochs_test_results.gz'
)
vsd_alexnet_initialize_results_gz = vsd_results_dir.joinpath(
    'VSD_alexnet_initialize_lr_1e-03/'
    'VSD_alexnet_initialize_lr_1e-03_trained_200_epochs_test_results.gz'
)

vsd_results_csv_alexnet_transfer = DATA_ROOT.joinpath('csv/VSD_alexnet_transfer_lr_1e-03_no_finetune_test.csv')
vsd_results_csv_alexnet_initialize = DATA_ROOT.joinpath('csv/VSD_alexnet_initialize_lr_1e-03_test.csv')

vsd_cornet_z_transfer_results_gz = vsd_results_dir.joinpath(
    'VSD_CORnet_Z_transfer_lr_1e-03_no_finetune/'
    'VSD_CORnet_Z_transfer_lr_1e-03_no_finetune_trained_200_epochs_test_results.gz'
)
vsd_cornet_z_initialize_results_gz = vsd_results_dir.joinpath(
    'VSD_CORnet_Z_initialize_lr_1e-03/'
    'VSD_CORnet_Z_initialize_lr_1e-03_trained_200_epochs_test_results.gz'
)

vsd_results_csv_cornet_z_transfer = DATA_ROOT.joinpath('csv/VSD_CORnet_Z_transfer_lr_1e-03_no_finetune_test.csv')
vsd_results_csv_cornet_z_initialize = DATA_ROOT.joinpath('csv/VSD_CORnet_Z_transfer_lr_1e-03_no_finetune_test.csv')

# %%
COL_NAMES_FOR_X = ['acc_model_1', 'acc_model_2',
                   'acc_model_3',  'acc_model_4',
                   'acc_model_5',  'acc_model_6',
                   'acc_model_7',  'acc_model_8',
                   'mean_acc']

def diff_score_v_mean_acc(df):
    fig, ax = plt.subplots(3, 3, figsize=(10, 10))
    ax = ax.ravel()
    for ind, x in enumerate(COL_NAMES_FOR_X):
        if ind != 8:
            sns.violinplot(x=x, y="difficulty_score",
                           data=df,
                           ax=ax[ind]);
        else:
            sns.regplot(x=x, y="difficulty_score",
                        data=df,
                        ax=ax[ind]);

    fig.tight_layout()

# %% [markdown]
# ## Introduction
#
# ANN models provide predictions of target detection when performing visual search of simplified stimuli used for lab tasks, but do they also provide predictions for visual search of complex natural images?
#
# The Visual Search Difficulty dataset (http://image-difficulty.herokuapp.com/) provides visual search difficulty scores for a subset of natural images from the PASCAL-VOC image dataset. The scores are derived from crowd-sourced human reaction times while searching for specified classes of objects in each image.
#
# To test whether ANN models predict target detection on complex natural stimuli, different ANN models were trained on a subset of the images used for the VSD scores and then their accuracy was correlated with the VSD scores on a separate test set.

# %% [markdown]
# ## plot results of training models on Visual Search Difficulty

# %%
vsd_df_alexnet_transfer = searchnets.utils.munge.vsd_results_df(vsd_alexnet_transfer_results_gz)
vsd_df_alexnet_transfer.to_csv(vsd_results_csv_alexnet_transfer)
# Out:
# Using downloaded and verified file: /home/bart/Documents/data/voc/VOCtrainval_11-May-2012.tar
# batch 0 of 46:   0%|          | 0/46 [00:08<?, ?it/s]/home/bart/anaconda3/envs/searchnets-torch/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# batch 45 of 46: 100%|██████████| 46/46 [00:25<00:00,  1.80it/s]
# /home/bart/Documents/repos/L2M/visual-search-nets/src/searchnets/utils/munge.py:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vsd_df_test[column_name] = values

# %% [markdown]
# ### Alexnet results

# %%
vsd_df_alexnet_transfer = pd.read_csv(vsd_results_csv_alexnet_transfer)
diff_score_v_mean_acc(vsd_df_alexnet_transfer)

# %% [markdown]
# Axes 1-8 are results for each training replicate.
# Violin plots are used to show the distribution of scores.
# Axes 9 is the correlation between the mean accuracy across all training replicates with the visual search difficulty score, for each image in the test set.
#
# I have not measured the correlation, but my guess it is "weak but significant". The distribution of visual search difficulty scores is itself not very linear; the majority fall within the range of 2-3 with just a few extreme scores at either end (0-1 or 3-5).

# %%
vsd_df_alexnet_initialize = searchnets.utils.munge.vsd_results_df(vsd_alexnet_initialize_results_gz)
vsd_df_alexnet_initialize.to_csv(vsd_results_csv_alexnet_initialize)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-edc7dd933f1b> in <module>
# ----> 1 vsd_df_alexnet_initialize = searchnets.utils.munge.vsd_results_df(vsd_alexnet_initialize_results_gz)
#       2 vsd_df_alexnet_initialize.to_csv(vsd_results_csv_alexnet_initialize)
#
# ~/Documents/repos/L2M/visual-search-nets/src/searchnets/utils/munge.py in vsd_results_df(results_gz, root, pad_size, batch_size, num_workers, results_csv_path)
#     168     vsd_df_test = vsd_df[vsd_df['split'] == 'test']
#     169
# --> 170     results = joblib.load(results_gz)
#     171     # model paths to checkpoint with saved model, *** used as keys for dicts in results_gz files ***
#     172     # in theory they should be sorted numerically already because they were added to the dictionary in the loop
#
# ~/anaconda3/envs/searchnets-torch/lib/python3.6/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     588             obj = _unpickle(fobj)
#     589     else:
# --> 590         with open(filename, 'rb') as f:
#     591             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     592                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../data/results/VSD_alexnet_initialize_lr_1e-03/VSD_alexnet_initialize_lr_1e-03_trained_200_epochs_test_results.gz'

# %%
vsd_df_alexnet_transfer = pd.read_csv(vsd_results_csv_alexnet_transfer)
diff_score_v_mean_acc(vsd_df_alexnet_transfer)

# %%
vsd_df_CORnet_Z = searchnets.utils.munge.vsd_results_df(vsd_cornet_z_results_gz)

# %% [markdown]
# ### CORnet Z results

# %%
vsd_df_CORnet_Z = pd.read_csv(vsd_results_csv_cornet_z)
diff_score_v_mean_acc(vsd_df_CORnet_Z)

# %% [markdown]
# Axes 1-8 are results for each training replicate.
# Violin plots are used to show the distribution of scores.
# Axes 9 is the correlation between the mean accuracy across all training replicates with the visual search difficulty score, for each image in the test set.
#
# CORnet Z does not by eye appear to be significantly different from AlexNet.
#
# One question is whether the CORNet model that incorporates more "brain-like" architectural constraints will provide different predictions.

# %%
vsd_df_alexnet['mean_err'] = 1 - vsd_df_alexnet['mean_acc']

# %%
vsd_df_CORnet_Z['mean_err'] = 1 - vsd_df_CORnet_Z['mean_acc']

# %%
def plot_mean_acc(ax, df, net, ylabel=False, xlim=(0.0, 0.26)):
    sns.regplot(x='mean_err', y="difficulty_score",
            data=df,
            ax=ax);
    ax.set_title(net)
    ax.set_xlabel('mean error')
    if ylabel:
        ax.set_ylabel('difficulty score')
    else:
        ax.set_ylabel('')
    ax.set_xlim(xlim)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax = ax.ravel()

plot_mean_acc(ax[0], vsd_df_alexnet, 'AlexNet', ylabel=True)

plot_mean_acc(ax[1], vsd_df_CORnet_Z, 'CORnet Z')

fig_filename = FIGDIR.joinpath('VSD_results.svg')
plt.savefig(fig_filename)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax = ax.ravel()

plot_mean_acc(ax[0], vsd_df_alexnet, 'AlexNet', ylabel=True)

plot_mean_acc(ax[1], vsd_df_CORnet_Z, 'CORnet Z')

fig_filename = FIGDIR.joinpath('VSD_results.png')
plt.savefig(fig_filename)
